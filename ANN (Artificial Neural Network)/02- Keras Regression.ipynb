# %% [markdown]
# ## Keras Regression
#
# ## The Data
#
# We will be using data from a Kaggle data set:
#
# https://www.kaggle.com/harlfoxem/housesalesprediction
#
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Data\data tensorflow\kc_house_data.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
# missing values
df_null = round(100*df.isna().sum()/len(df), 2)
df_null
# Out:
# id               0.0
# date             0.0
# price            0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# grade            0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# zipcode          0.0
# lat              0.0
# long             0.0
# sqft_living15    0.0
# sqft_lot15       0.0
# dtype: float64

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.style.use(['science','notebook','grid'])

# %%
plt.figure(figsize=(9, 5), dpi=100)
sns.distplot(df['price']);
# Out:
# C:\Users\ibrahim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5), dpi=100)
ax = sns.countplot(x='bedrooms', data =df)

for p in ax.patches:
    height = p.get_height() + 10
    ax.text(x = p.get_x() + p.get_width()/ 2, 
            y = height + 100, 
            s = '{:.0f}'.format(height), 
            ha = 'center')
plt.title('Total Bedrooms')
plt.show()

# %% [markdown]
# ## Chek correlation

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
plt.figure(figsize=(7, 5), dpi=100)
sns.scatterplot(x='price', y='sqft_living', data = df, s=100);
plt.title('price VS sqft_living');

# %%
plt.figure(figsize=(10, 5), dpi=100)
sns.boxplot(x='bedrooms', y='price', data=df);
plt.title('Bedrooms vs Price');

# %% [markdown]
# ## Letak geografis properti

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.scatterplot(x='price', y='long', data=df, s=100);
plt.title('Longitude vs Price');

# %% [markdown]
# rumah yang mempunya harga tertingi berada di long `-122.2`

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.scatterplot(x='price', y='lat', data=df, s=100);
plt.title('Longitude vs Price');

# %% [markdown]
# rumah yang mempunya harga tertingi berada di antara lat `47.6 - 47.7`

# %%
plt.figure(figsize=(12, 7), dpi=100)
sns.scatterplot(x='long', y='lat', hue='price', data=df, s=100);

# %%
df.sort_values('price', ascending=False).head(10)
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 8092         9640     13068     1.0           1     4  ...     12        4820
# 2626         6640     40014     2.0           1     4  ...     12        6350
# 8638         6430     27517     2.0           0     0  ...     12        6430
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
# 3914           2360      1940          2001    98004  47.6500 -122.214
# 9254           1030      2001             0    98039  47.6305 -122.240
# 4411           3000      2001             0    98039  47.6289 -122.233
# 1448           1280      2009             0    98004  47.6232 -122.220
# 1315           2390      1991             0    98040  47.5631 -122.210
# 1164           2020      1999             0    98033  47.6767 -122.211
# 8092           4820      1983          2009    98040  47.5570 -122.210
# 2626            290      2004             0    98155  47.7493 -122.280
# 8638              0      2001             0    98004  47.6208 -122.219
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
# 3914           3930       25449
# 9254           4540       42730
# 4411           3560       24345
# 1448           4600       21750
# 1315           4320       24619
# 1164           3430       26788
# 8092           3270       10454
# 2626           3030       23408
# 8638           3720       14592
#
# [10 rows x 21 columns]

# %%
df.loc[7252]
# Out:
# id                    6762700020
# date             20141013T000000
# price                  7700000.0
# bedrooms                       6
# bathrooms                    8.0
# sqft_living                12050
# sqft_lot                   27600
# floors                       2.5
# waterfront                     0
# view                           3
# condition                      4
# grade                         13
# sqft_above                  8570
# sqft_basement               3480
# yr_built                    1910
# yr_renovated                1987
# zipcode                    98102
# lat                      47.6298
# long                    -122.323
# sqft_living15               3940
# sqft_lot15                  8800
# Name: 7252, dtype: object

# %% [markdown]
# Harga tertinggi rumah 7700000 dollars

# %%
# jumlah data rumah 10% dari outlier
len(df) * 0.10
# Out:
# 2161.3

# %%
non_top_percent = df.sort_values('price', ascending=False).iloc[216:]

# %%
non_top_percent
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3281   8964800025  20150226T000000  1965000.0         5       3.75
# 12577  2806300065  20150422T000000  1960000.0         4       4.00
# 12283  1923000260  20141015T000000  1959000.0         5       4.50
# 1152   4055701200  20150421T000000  1955000.0         4       2.75
# 9175   3124059023  20150213T000000  1955000.0         3       1.75
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3281          3940     13738     1.5           0     3  ...      9
# 12577         4430     31353     2.0           0     0  ...     12
# 12283         6200     23373     3.0           0     1  ...     11
# 1152          3120      7898     1.0           1     4  ...      8
# 9175          3330     12566     1.0           1     4  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 8274           860     10426     1.0           0     0  ...      6
# 16198          730      9975     1.0           0     0  ...      5
# 465            430      5050     1.0           0     0  ...      4
# 15293          780     16344     1.0           0     0  ...      5
# 1149           670     43377     1.0           0     0  ...      3
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3281         3940              0      1951             0    98004  47.6203
# 12577        4430              0      1998             0    98005  47.6422
# 12283        5050           1150      1988             0    98040  47.5632
# 1152         1560           1560      1963             0    98034  47.7165
# 9175         1940           1390      1960             0    98040  47.5287
# ...           ...            ...       ...           ...      ...      ...
# 8274          860              0      1954             0    98146  47.4987
# 16198         730              0      1943             0    98168  47.4808
# 465           430              0      1912             0    98014  47.6499
# 15293         780              0      1942             0    98168  47.4739
# 1149          670              0      1966             0    98022  47.2638
#
#           long  sqft_living15  sqft_lot15
# 3281  -122.212           2370       13320
# 12577 -122.157           3900       35237
# 12283 -122.215           3700       14486
# 1152  -122.259           2630       13868
# 9175  -122.220           3730       16560
# ...        ...            ...         ...
# 8274  -122.341           1140       11250
# 16198 -122.315            860        9000
# 465   -121.909           1200        7500
# 15293 -122.280           1700       10387
# 1149  -121.906           1160       42882
#
# [21397 rows x 21 columns]

# %%
plt.figure(figsize=(12, 9), dpi=100)
sns.scatterplot(x='long', y='lat', hue='price', data =non_top_percent, palette='ocean', s=100, edgecolor=None, alpha=0.2);

# %% [markdown]
# Warna biru pada ploting merupakan area yan berada di kawasan tepi air (`waterfront`), wajar bila harganya mahal

# %%
plt.figure(figsize=(7, 5), dpi =100)
sns.boxplot(x='waterfront', y='price', data=df, palette='ocean');

# %% [markdown]
# ----------
# ## Feature engenering

# %%
df.head(2)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
# hapus kolom id
df = df.drop('id', axis =1)
df.head(2)
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639

# %%
# kolom date 
df['date'].dtype
# Out:
# dtype('O')

# %%
# merubah type data pada kolom date
df['date'] = pd.to_datetime(df['date'])

# %%
# kolom tahun
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %% [markdown]
# ## Mengekstrak kolom date

# %%
# year
df['year'] = df['date'].apply(lambda date: date.year)

# %%
# month
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head(2)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# 0    98178  47.5112 -122.257           1340        5650  2014     10
# 1    98125  47.7210 -122.319           1690        7639  2014     12
#
# [2 rows x 22 columns]

# %%
df = df.drop('date', axis =1)

# %%
df.head(2)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# 0    98178  47.5112 -122.257           1340        5650  2014     10
# 1    98125  47.7210 -122.319           1690        7639  2014     12
#
# [2 rows x 21 columns]

# %%
plt.figure(figsize=(8,5), dpi=100)
sns.boxplot(x='year', y='price', data=df);

# %%
plt.figure(figsize=(12, 6), dpi=100)
sns.boxplot(x='month', y='price', data=df);

# %% [markdown]
# ## Pegecekan harga rata-rata perbulan di setiap bulannya

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525870.889571
# 2     507851.371200
# 3     543977.187200
# 4     561837.774989
# 5     550768.785833
# 6     558002.199541
# 7     544788.764360
# 8     536445.276804
# 9     529253.821871
# 10    539026.971778
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot();
plt.title('Average Price per month');

# %% [markdown]
# ## Pegecekan harga rata-rata pertahun di setiap tahunnya

# %%
df.groupby('year').mean()['price']
# Out:
# year
# 2014    539181.428415
# 2015    541988.992264
# Name: price, dtype: float64

# %%
df.groupby('year').mean()['price'].plot();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
#  19  year           21613 non-null  int64
#  20  month          21613 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 3.5 MB

# %%
df['zipcode']
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21608    98103
# 21609    98146
# 21610    98144
# 21611    98027
# 21612    98144
# Name: zipcode, Length: 21613, dtype: int64

# %%
df = df.drop('zipcode', axis =1)

# %%
df.head(3)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
# 1  47.7210 -122.319           1690        7639  2014     12
# 2  47.7379 -122.233           2720        8062  2015      2

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# -------------
# ## Train Test Split

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=101)

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
X_test.shape
# Out:
# (6484, 19)

# %%
y_train.shape
# Out:
# (15129,)

# %%
y_test.shape
# Out:
# (6484,)

# %% [markdown]
# ------
# ## Scaler data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
X_test.shape
# Out:
# (6484, 19)

# %% [markdown]
# -----
# ## Create Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ## Add EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor ='val_loss', patience=2)

# %% [markdown]
# ## Fitting Model
# batch size = 32, 64, 128, 256, 512

# %%
model.fit(X_train, y_train, 
          epochs= 200, 
          batch_size= 128, 
          validation_data =(X_test, y_test), 
          callbacks=[early_stop]
         )
# Out:
# Epoch 1/200
# 119/119 [==============================] - 6s 19ms/step - loss: 423608877056.0000 - val_loss: 432909058048.0000
# Epoch 2/200
# 119/119 [==============================] - 1s 11ms/step - loss: 421011980288.0000 - val_loss: 423132528640.0000
# Epoch 3/200
# 119/119 [==============================] - 1s 10ms/step - loss: 379270660096.0000 - val_loss: 324951965696.0000
# Epoch 4/200
# 119/119 [==============================] - 1s 9ms/step - loss: 212568932352.0000 - val_loss: 125503111168.0000
# Epoch 5/200
# 119/119 [==============================] - 1s 9ms/step - loss: 111487705088.0000 - val_loss: 104350081024.0000
# Epoch 6/200
# 119/119 [==============================] - 1s 9ms/step - loss: 106835345408.0000 - val_loss: 102227345408.0000
# Epoch 7/200
# 119/119 [==============================] - 1s 10ms/step - loss: 106818781184.0000 - val_loss: 99974135808.0000
# Epoch 8/200
# 119/119 [==============================] - 1s 9ms/step - loss: 103902887936.0000 - val_loss: 97866997760.0000
# Epoch 9/200
# 119/119 [==============================] - 1s 10ms/step - loss: 100388831232.0000 - val_loss: 95868829696.0000
# Epoch 10/200
# 119/119 [==============================] - 1s 11ms/step - loss: 99431956480.0000 - val_loss: 93157490688.0000
# Epoch 11/200
# 119/119 [==============================] - 1s 11ms/step - loss: 96989700096.0000 - val_loss: 90903838720.0000
# Epoch 12/200
# 119/119 [==============================] - 2s 13ms/step - loss: 95143370752.0000 - val_loss: 88200298496.0000
# Epoch 13/200
# 119/119 [==============================] - 1s 12ms/step - loss: 93029146624.0000 - val_loss: 86017531904.0000
# Epoch 14/200
# 119/119 [==============================] - 1s 11ms/step - loss: 89873809408.0000 - val_loss: 82396594176.0000
# Epoch 15/200
# 119/119 [==============================] - 1s 12ms/step - loss: 87090765824.0000 - val_loss: 79589376000.0000
# Epoch 16/200
# 119/119 [==============================] - 1s 11ms/step - loss: 83750371328.0000 - val_loss: 76797419520.0000
# Epoch 17/200
# 119/119 [==============================] - 1s 11ms/step - loss: 81386422272.0000 - val_loss: 73320128512.0000
# Epoch 18/200
# 119/119 [==============================] - 1s 10ms/step - loss: 78341414912.0000 - val_loss: 69922742272.0000
# Epoch 19/200
# 119/119 [==============================] - 1s 10ms/step - loss: 75299676160.0000 - val_loss: 67039404032.0000
# Epoch 20/200
# 119/119 [==============================] - 1s 10ms/step - loss: 71448559616.0000 - val_loss: 63834300416.0000
# Epoch 21/200
# 119/119 [==============================] - 1s 10ms/step - loss: 70725877760.0000 - val_loss: 61091819520.0000
# Epoch 22/200
# 119/119 [==============================] - 1s 11ms/step - loss: 66742415360.0000 - val_loss: 58858713088.0000
# Epoch 23/200
# 119/119 [==============================] - 1s 12ms/step - loss: 66777595904.0000 - val_loss: 57237786624.0000
# Epoch 24/200
# 119/119 [==============================] - 1s 11ms/step - loss: 64462987264.0000 - val_loss: 55564251136.0000
# Epoch 25/200
# 119/119 [==============================] - 1s 11ms/step - loss: 62948790272.0000 - val_loss: 53819691008.0000
# Epoch 26/200
# 119/119 [==============================] - 1s 12ms/step - loss: 61635661824.0000 - val_loss: 52493664256.0000
# Epoch 27/200
# 119/119 [==============================] - 1s 11ms/step - loss: 61996924928.0000 - val_loss: 51587379200.0000
# Epoch 28/200
# 119/119 [==============================] - 1s 11ms/step - loss: 61184806912.0000 - val_loss: 51069665280.0000
# Epoch 29/200
# 119/119 [==============================] - 1s 11ms/step - loss: 59963711488.0000 - val_loss: 50239188992.0000
# Epoch 30/200
# 119/119 [==============================] - 1s 10ms/step - loss: 59272962048.0000 - val_loss: 49580093440.0000
# Epoch 31/200
# 119/119 [==============================] - 1s 9ms/step - loss: 58444693504.0000 - val_loss: 49539997696.0000
# Epoch 32/200
# 119/119 [==============================] - 1s 10ms/step - loss: 57502978048.0000 - val_loss: 48652746752.0000
# Epoch 33/200
# 119/119 [==============================] - 1s 10ms/step - loss: 57490272256.0000 - val_loss: 47993229312.0000
# Epoch 34/200
# 119/119 [==============================] - 1s 11ms/step - loss: 56163573760.0000 - val_loss: 47303061504.0000
# Epoch 35/200
# 119/119 [==============================] - 1s 12ms/step - loss: 56241324032.0000 - val_loss: 47221620736.0000
# Epoch 36/200
# 119/119 [==============================] - 1s 12ms/step - loss: 57295507456.0000 - val_loss: 46350520320.0000
# Epoch 37/200
# 119/119 [==============================] - 2s 15ms/step - loss: 56308330496.0000 - val_loss: 46529425408.0000
# Epoch 38/200
# 119/119 [==============================] - 1s 12ms/step - loss: 54314434560.0000 - val_loss: 45586780160.0000
# Epoch 39/200
# 119/119 [==============================] - 1s 11ms/step - loss: 56408252416.0000 - val_loss: 45485461504.0000
# Epoch 40/200
# 119/119 [==============================] - 1s 12ms/step - loss: 54173216768.0000 - val_loss: 44924166144.0000
# Epoch 41/200
# 119/119 [==============================] - 1s 11ms/step - loss: 54657982464.0000 - val_loss: 44244840448.0000
# Epoch 42/200
# 119/119 [==============================] - 1s 11ms/step - loss: 54482952192.0000 - val_loss: 44048441344.0000
# Epoch 43/200
# 119/119 [==============================] - 1s 10ms/step - loss: 54395879424.0000 - val_loss: 44044435456.0000
# Epoch 44/200
# 119/119 [==============================] - 1s 10ms/step - loss: 52723662848.0000 - val_loss: 43304742912.0000
# Epoch 45/200
# 119/119 [==============================] - 1s 10ms/step - loss: 52402376704.0000 - val_loss: 43458367488.0000
# Epoch 46/200
# 119/119 [==============================] - 1s 12ms/step - loss: 52988502016.0000 - val_loss: 42895536128.0000
# Epoch 47/200
# 119/119 [==============================] - 1s 11ms/step - loss: 52919144448.0000 - val_loss: 42765643776.0000
# Epoch 48/200
# 119/119 [==============================] - 1s 11ms/step - loss: 52336074752.0000 - val_loss: 42115686400.0000
# Epoch 49/200
# 119/119 [==============================] - 1s 11ms/step - loss: 52082790400.0000 - val_loss: 41800642560.0000
# Epoch 50/200
# 119/119 [==============================] - 1s 11ms/step - loss: 51261538304.0000 - val_loss: 41594490880.0000
# Epoch 51/200
# 119/119 [==============================] - 1s 11ms/step - loss: 52212535296.0000 - val_loss: 41701519360.0000
# Epoch 52/200
# 119/119 [==============================] - 1s 11ms/step - loss: 51784069120.0000 - val_loss: 41130332160.0000
# Epoch 53/200
# 119/119 [==============================] - 1s 11ms/step - loss: 51235696640.0000 - val_loss: 40914956288.0000
# Epoch 54/200
# 119/119 [==============================] - 1s 11ms/step - loss: 52077342720.0000 - val_loss: 40705785856.0000
# Epoch 55/200
# 119/119 [==============================] - 1s 9ms/step - loss: 51389034496.0000 - val_loss: 40752279552.0000
# Epoch 56/200
# 119/119 [==============================] - 1s 10ms/step - loss: 51218505728.0000 - val_loss: 41107456000.0000

# %% [markdown]
# ## Evaluation

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#             loss      val_loss
# 0   4.236089e+11  4.329091e+11
# 1   4.210120e+11  4.231325e+11
# 2   3.792707e+11  3.249520e+11
# 3   2.125689e+11  1.255031e+11
# 4   1.114877e+11  1.043501e+11
# 5   1.068353e+11  1.022273e+11
# 6   1.068188e+11  9.997414e+10
# 7   1.039029e+11  9.786700e+10
# 8   1.003888e+11  9.586883e+10
# 9   9.943196e+10  9.315749e+10
# 10  9.698970e+10  9.090384e+10
# 11  9.514337e+10  8.820030e+10
# 12  9.302915e+10  8.601753e+10
# 13  8.987381e+10  8.239659e+10
# 14  8.709077e+10  7.958938e+10
# 15  8.375037e+10  7.679742e+10
# 16  8.138642e+10  7.332013e+10
# 17  7.834141e+10  6.992274e+10
# 18  7.529968e+10  6.703940e+10
# 19  7.144856e+10  6.383430e+10
# 20  7.072588e+10  6.109182e+10
# 21  6.674242e+10  5.885871e+10
# 22  6.677760e+10  5.723779e+10
# 23  6.446299e+10  5.556425e+10
# 24  6.294879e+10  5.381969e+10
# 25  6.163566e+10  5.249366e+10
# 26  6.199692e+10  5.158738e+10
# 27  6.118481e+10  5.106967e+10
# 28  5.996371e+10  5.023919e+10
# 29  5.927296e+10  4.958009e+10
# 30  5.844469e+10  4.954000e+10
# 31  5.750298e+10  4.865275e+10
# 32  5.749027e+10  4.799323e+10
# 33  5.616357e+10  4.730306e+10
# 34  5.624132e+10  4.722162e+10
# 35  5.729551e+10  4.635052e+10
# 36  5.630833e+10  4.652943e+10
# 37  5.431443e+10  4.558678e+10
# 38  5.640825e+10  4.548546e+10
# 39  5.417322e+10  4.492417e+10
# 40  5.465798e+10  4.424484e+10
# 41  5.448295e+10  4.404844e+10
# 42  5.439588e+10  4.404444e+10
# 43  5.272366e+10  4.330474e+10
# 44  5.240238e+10  4.345837e+10
# 45  5.298850e+10  4.289554e+10
# 46  5.291914e+10  4.276564e+10
# 47  5.233607e+10  4.211569e+10
# 48  5.208279e+10  4.180064e+10
# 49  5.126154e+10  4.159449e+10
# 50  5.221254e+10  4.170152e+10
# 51  5.178407e+10  4.113033e+10
# 52  5.123570e+10  4.091496e+10
# 53  5.207734e+10  4.070579e+10
# 54  5.138903e+10  4.075228e+10
# 55  5.121851e+10  4.110746e+10

# %%
losses.plot();
plt.title('Cross-Entropy Loss');

# %% [markdown]
# ## prediction

# %%
prediction  = model.predict(X_test)
# Out:
# 203/203 [==============================] - 2s 5ms/step

# %%
prediction
# Out:
# array([[450710.78],
#        [597033.6 ],
#        [499843.7 ],
#        ...,
#        [529498.94],
#        [145720.47],
#        [841660.  ]], dtype=float32)

# %% [markdown]
# ## Evaluation on test data

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
MAE = mean_absolute_error(y_test,prediction )
print(f'MAE : {MAE}')
# Out:
# MAE : 120436.23908054321

# %%
MSE = mean_squared_error(y_test, prediction)
print(f'MSE : {MSE}')
# Out:
# MSE : 41107450160.0875

# %%
RMSE = np.sqrt(MSE)
print(f'RMSE : {RMSE}')
# Out:
# RMSE : 202749.722959336

# %% [markdown]
# ## Compire final evaluation MSE

# %%
training_score = model.evaluate(X_train, y_train, verbose=0)

# %%
test_score = model.evaluate(X_test, y_test, verbose = 0)

# %%
training_score, test_score # diharapkan angkanya mendekati
# Out:
# (40894050304.0, 41107464192.0)

# %% [markdown]
# ---------
# ## Cek rata-rata price

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
mean_price = df['price'].mean()
mean_price
# Out:
# 540088.1417665294

# %%
(100 * MAE)/mean_price
# Out:
# 22.29936741188546

# %% [markdown]
# ----------
# ## Explaned variance score

# %%
explained_variance_score(y_test, prediction)
# Out:
# 0.7115953490769094

# %%
plt.figure(figsize=(10,6),dpi=100)

plt.scatter(y_test, prediction, s=100)

plt.plot(y_test, y_test, 'r');

# %% [markdown]
# ## Plot Error

# %%
prediction.shape
# Out:
# (6484, 1)

# %%
error = y_test.reshape(6484, 1) - prediction

# %%
error
# Out:
# array([[-100760.78125],
#        [-147033.625  ],
#        [ 135156.3125 ],
#        ...,
#        [-135248.9375 ],
#        [ 103779.53125],
#        [ 508340.     ]])

# %%
sns.distplot(error);
# Out:
# C:\Users\ibrahim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Prediction new House

# %%
single_house = df.drop('price', axis =1).iloc[0]

# %%
single_house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# Name: 0, dtype: float64

# %%
single_house.shape
# Out:
# (19,)

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
single_house
# Out:
# array([[0.27272727, 0.125     , 0.06716981, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.5       , 0.09758772,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00573322, 0.        , 0.81818182]])

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 108ms/step
# array([[230336.7]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# year               2014.0000
# month                10.0000
# Name: 0, dtype: float64

# %% [markdown]
# **Kesimpulan :**  dari model yan telah kita buat dapat di katakan baik karena hasil prediksi rumah `230336.7` mendekati harga sebenarnya `221900.0` nyaris sempurna
